# %%
# note: these weights for each answer will be obtained
#       once we have the data to train on. The current
#       numbers are just placeholders. 

def questionAssessment(q):
    point = 0
    if q.id == '0':
        if q.choices == [1,0,0,0]:
            point += 1
        elif q.choice == [0,1,0,0]:
            point += 0.88
        elif q.choice == [0,0,1,0]:
            point += 0.71
        elif q.choice == [0,0,0,1]:
            point += 0.43
    
    elif q.id == '1':
        if q.choices == [1,0,0,0]:
            point += 1
        elif q.choice == [0,1,0,0]:
            point += 0.88
        elif q.choice == [0,0,1,0]:
            point += 0.71
        elif q.choice == [0,0,0,1]:
            point += 0.43
    
    elif q.id == '2':
        if q.choices == [1,0]:
            point += 1
        elif q.choice == [0,1]:
            point += 0.88
    
    elif q.id == '3':
        if q.choices == [1,0]:
            point += 1
        elif q.choice == [0,1]:
            point += 0.88
    
    elif q.id == '4':
        if q.choices == [1,0]:
            point += 1
        elif q.choice == [0,1]:
            point += 0.88
            
    elif q.id == '5':
        if q.choices == [1,0,0,0]:
            point += 1
        elif q.choice == [0,1,0,0]:
            point += 0.88
        elif q.choice == [0,0,1,0]:
            point += 0.71
        elif q.choice == [0,0,0,1]:
            point += 0.43
    
    elif q.id == '6':
        if q.choices == [1,0,0,0]:
            point += 1
        elif q.choice == [0,1,0,0]:
            point += 0.88
        elif q.choice == [0,0,1,0]:
            point += 0.71
    
    elif q.id == '7':
        if q.choices == [1,0,0,0]:
            point += 1
        elif q.choice == [0,1,0,0]:
            point += 0.88
        elif q.choice == [0,0,1,0]:
            point += 0.71
        elif q.choice == [0,0,0,1]:
            point += 0.43
    return point

# %%
# import data to variable called data
data = {}

def buildClass(data):
    pointTotal = 0
    for q in data:
        pointTotal += questionAssessment(q)
    return pointTotal
